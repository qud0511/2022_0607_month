# %%
# 모듈 로딩
import pandas as pd
# 1.'남북한발전전력량.xlsx’에서 아래 결과를 도출하세요.
# 1) DataFrame형식으로 데이터를 가져오세요.
ele=pd.read_excel('../Data/남북한발전전력량.xlsx')
ele
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
# 2) 요약정보 출력해주세요.
ele.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전력량 (억㎾h)  2 non-null      object
#  1   발전 전력별     9 non-null      object
#  2   1990       9 non-null      object
#  3   1991       9 non-null      object
#  4   1992       9 non-null      object
#  5   1993       9 non-null      object
#  6   1994       9 non-null      object
#  7   1995       9 non-null      object
#  8   1996       9 non-null      object
#  9   1997       9 non-null      object
#  10  1998       9 non-null      object
#  11  1999       9 non-null      object
#  12  2000       9 non-null      object
#  13  2001       9 non-null      object
#  14  2002       9 non-null      object
#  15  2003       9 non-null      object
#  16  2004       9 non-null      object
#  17  2005       9 non-null      object
#  18  2006       9 non-null      object
# ...

# %%
# 3) 1990~2016 컬럼에서 컬럼별 최대값, 최소값을 출력해주세요.
ele1=pd.read_excel('../Data/남북한발전전력량.xlsx')
ele1_re4=ele1.iloc[:8,:].drop(index=4)
ele1_re4
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 5   255   235   237   211   215   221   216   190   239
# ...

# %%
ele1_re4.mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7240\3919159167.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ele1_re4.mean()
# 1990     386.857143
# 1991     414.142857
# 1992     444.857143
# 1993     475.714286
# 1994     537.428571
# 1995     593.428571
# 1996     648.000000
# 1997     696.428571
# 1998     663.714286
# 1999     737.000000
# 2000     816.571429
# 2001     872.571429
# 2002     930.000000
# 2003     977.428571
# 2004    1036.428571
# 2005    1103.285714
# 2006    1153.285714
# 2007    1219.000000
# 2008    1279.714286
# 2009    1306.000000
# 2010    1424.000000
# 2011    1479.857143
# 2012    1505.142857
# 2013    1523.714286
# 2014    1531.571429
# 2015    1538.428571
# 2016    1584.428571
# dtype: float64

# %%
ele1.iloc[4][2:-5]=ele1_re4.mean()[:-5]
ele1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7240\2563784293.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ele1.iloc[4][2:-5]=ele1_re4.mean()[:-5]
#   전력량 (억㎾h) 발전 전력별        1990        1991        1992        1993  \
# 0        남한     합계        1077        1186        1310        1444
# 1       NaN     수력          64          51          49          60
# 2       NaN     화력         484         573         696         803
# 3       NaN    원자력         529         563         565         581
# 4       NaN    신재생  386.857143  414.142857  444.857143  475.714286
# 5        북한     합계         277         263         247         221
# 6       NaN     수력         156         150         142         133
# 7       NaN     화력         121         113         105          88
# ...

# %%
pd.DataFrame({'최대값':ele1.iloc[:8,2:].max(),'최소값':ele1.iloc[:8,2:].min()}).transpose()
# Out:
#      1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  2007  \
# 최대값  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  ...  4031
# 최소값    64    51    49    60    41    55    52    54    61    61  ...    50
#
#      2008  2009  2010  2011  2012  2013  2014  2015  2016
# 최대값  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 최소값    56    56    65    78    77    82    78    58    66
#
# [2 rows x 27 columns]

# %%
# 4) 1990~2016 컬럼에서 짝수 컬럼 데이터만 출력해주세요.
ele.iloc[:,2::2]
# Out:
#    1990  1992  1994  1996  1998  2000  2002  2004  2006  2008  2010  2012  \
# 0  1077  1310  1650  2055  2153  2664  3065  3421  3812  4224  4747  5096
# 1    64    49    41    52    61    56    53    59    52    56    65    77
# 2   484   696  1022  1264  1195  1518  1821  2056  2272  2658  3196  3430
# 3   529   565   587   739   897  1090  1191  1307  1487  1510  1486  1503
# 4     -     -     -     -     -     -     -     -     -     -     -    86
# 5   277   247   231   213   170   194   190   206   225   255   237   215
# 6   156   142   138   125   102   102   106   125   126   141   134   135
# 7   121   105    93    88    68    92    84    81    99   114   103    80
# 8     -     -     -     -     -     -     -     -     -     -     -     -
#
#    2014  2016
# 0  5220  5404
# 1    78    66
# 2  3427  3523
# 3  1564  1620
# 4   151   195
# 5   216   239
# 6   130   128
# 7    86   111
# 8     -     -

# %%
# 5) 전력량과 발전 전력별을 하나의 컬럼을 합치고 합친 걸럼을 추가해 주세요.
ele2=ele.fillna('')
eleTwo=ele2['전력량 (억㎾h)']+ele['발전 전력별']
ele2['발전전력별+량']=eleTwo
ele2
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2008  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4224
# 1               수력    64    51    49    60    41    55    52    54  ...    56
# 2               화력   484   573   696   803  1022  1122  1264  1420  ...  2658
# 3              원자력   529   563   565   581   587   670   739   771  ...  1510
# 4              신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   255
# 6               수력   156   150   142   133   138   142   125   107  ...   141
# 7               화력   121   113   105    88    93    88    88    86  ...   114
# 8              원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2009  2010  2011  2012  2013  2014  2015  2016 발전전력별+량
# 0  4336  4747  4969  5096  5171  5220  5281  5404    남한합계
# 1    56    65    78    77    84    78    58    66      수력
# ...

# %%
# 6) 5번에서 생성된 컬럼을 인덱스로 설정해 주세요.
ele3=ele2.set_index('발전전력별+량')
ele3
# Out:
#         전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 발전전력별+량                                                                   ...
# 남한합계           남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...
# 수력                    수력    64    51    49    60    41    55    52    54  ...
# 화력                    화력   484   573   696   803  1022  1122  1264  1420  ...
# 원자력                  원자력   529   563   565   581   587   670   739   771  ...
# 신재생                  신재생     -     -     -     -     -     -     -     -  ...
# 북한합계           북한     합계   277   263   247   221   231   230   213   193  ...
# 수력                    수력   156   150   142   133   138   142   125   107  ...
# 화력                    화력   121   113   105    88    93    88    88    86  ...
# 원자력                  원자력     -     -     -     -     -     -     -     -  ...
#
#          2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 발전전력별+량
# ...

# %%
# 2.'iris.csv’에서 아래 결과를 도출하세요.
iris=pd.read_csv('../Data/iris.csv')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Name         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 1) Length 데이터만 추출해서 출력해주세요.
list=[]
for i in iris.columns:
    if 'Length' in i:
        list+=[i]
iris[list]
# Out:
#      SepalLength  PetalLength
# 0            5.1          1.4
# 1            4.9          1.4
# 2            4.7          1.3
# 3            4.6          1.5
# 4            5.0          1.4
# ..           ...          ...
# 145          6.7          5.2
# 146          6.3          5.0
# 147          6.5          5.2
# 148          6.2          5.4
# 149          5.9          5.1
#
# [150 rows x 2 columns]

# %%
iris[['SepalLength','PetalLength']]
# Out:
#      SepalLength  PetalLength
# 0            5.1          1.4
# 1            4.9          1.4
# 2            4.7          1.3
# 3            4.6          1.5
# 4            5.0          1.4
# ..           ...          ...
# 145          6.7          5.2
# 146          6.3          5.0
# 147          6.5          5.2
# 148          6.2          5.4
# 149          5.9          5.1
#
# [150 rows x 2 columns]

# %%
iris.filter(regex='Length')
# Out:
#      SepalLength  PetalLength
# 0            5.1          1.4
# 1            4.9          1.4
# 2            4.7          1.3
# 3            4.6          1.5
# 4            5.0          1.4
# ..           ...          ...
# 145          6.7          5.2
# 146          6.3          5.0
# 147          6.5          5.2
# 148          6.2          5.4
# 149          5.9          5.1
#
# [150 rows x 2 columns]

# %%
# 2) SepalLength 컬럼에서 길이가 5.0보다 큰 걸럼의 SepalLength와 Names만 출력해주세요.
iris[iris['SepalLength']>5]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 14           5.8         4.0          1.2         0.2     Iris-setosa
# 15           5.7         4.4          1.5         0.4     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [118 rows x 5 columns]

# %%
iris_Length=iris[iris['SepalLength']>5]
iris_Length
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 14           5.8         4.0          1.2         0.2     Iris-setosa
# 15           5.7         4.4          1.5         0.4     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [118 rows x 5 columns]

# %%
iris_Length[['SepalLength','Name']]
# Out:
#      SepalLength            Name
# 0            5.1     Iris-setosa
# 5            5.4     Iris-setosa
# 10           5.4     Iris-setosa
# 14           5.8     Iris-setosa
# 15           5.7     Iris-setosa
# ..           ...             ...
# 145          6.7  Iris-virginica
# 146          6.3  Iris-virginica
# 147          6.5  Iris-virginica
# 148          6.2  Iris-virginica
# 149          5.9  Iris-virginica
#
# [118 rows x 2 columns]

# %%
# 3) Iris-setosa, Iris-versicolor, Iris-virginica에서 각각 최대, 최소 컬럼을 출력해 주세요.
setosa=iris[iris['Name']=='Iris-setosa']
print(f'setosa 최대 =>\n{setosa.max()}\nsetosa 최소 =>\n{setosa.min()}')
# Out:
# setosa 최대 =>
# SepalLength            5.8
# SepalWidth             4.4
# PetalLength            1.9
# PetalWidth             0.6
# Name           Iris-setosa
# dtype: object
# setosa 최소 =>
# SepalLength            4.3
# SepalWidth             2.3
# PetalLength            1.0
# PetalWidth             0.1
# Name           Iris-setosa
# dtype: object

# %%
versicolor=iris[iris['Name']=='Iris-versicolor']
print(f'versicolor 최대 =>\n{versicolor.max()}\versicolor 최소 =>\n{versicolor.min()}')
# Out:
# versicolor 최대 =>
# SepalLength                7.0
# SepalWidth                 3.4
# PetalLength                5.1
# PetalWidth                 1.8
# Name           Iris-versicolor
# dtype: objectersicolor 최소 =>
# SepalLength                4.9
# SepalWidth                 2.0
# PetalLength                3.0
# PetalWidth                 1.0
# Name           Iris-versicolor
# dtype: object

# %%
virginica=iris[iris['Name']=='Iris-virginica']
print(f'virginica 최대 =>\n{virginica.max()}\virginica 최소 =>\n{virginica.min()}')
# Out:
# virginica 최대 =>
# SepalLength               7.9
# SepalWidth                3.8
# PetalLength               6.9
# PetalWidth                2.5
# Name           Iris-virginica
# dtype: objectirginica 최소 =>
# SepalLength               4.9
# SepalWidth                2.2
# PetalLength               4.5
# PetalWidth                1.4
# Name           Iris-virginica
# dtype: object
