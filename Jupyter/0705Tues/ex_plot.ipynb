# %% [markdown]
# # 데이터 시각화
#     - pandas의 DF, SR의 내장 메서드 => plot() : Matplotlib 모듈 백그라운드 구동
#     - 외부패키지 Matplolib 사용 => 설치 필요
#     - 구성 - figure 객체, axex객체, axis 객체

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm, rc
import pandas as pd
import numpy as np

# %%
# 폰트 등록하기
FONT_PATH = '../Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=FONT_PATH).get_name()
rc('font', family=font_name)

# %%
# 그래프 그리기 => plot( [x_data], y_data )
plt.plot([1,2,3,4],[5,18,45,93])        # 데이터 입력
plt.ylabel('나의 데이터')                  # y축 라벨
plt.title('TEST')                       # 그래프 타이틀
plt.legend('a')                         # 범례
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure()

ax1 = fig.add_subplot(221)
ax1.set_title('LINE')
ax1.plot([1,2,3,4])

ax2 = fig.add_subplot(222)
ax2.set_title('OOO')
ax2.plot([11,33,22,44])

ax3 = fig.add_subplot(223)
ax3.set_title('Test')
ax3.plot([10,66,108,77], [1,2,3,4])

ax4 = fig.add_subplot(224)
ax4.set_title('OOO')
ax4.plot([11,33,22,44])
