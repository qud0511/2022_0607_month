# %%
# 모듈 로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm, rc
import seaborn as sns

# %%
# 폰트 등록
FONT_PATH = '../Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=FONT_PATH).get_name()
rc('font', family=font_name)
# 그래프의 한글 텍스트가 깨지지 않기 위함.

# %%
# 파일 관련 변수들
DIR = './Data/'
GOOGLE01 = DIR + 'Accommodation_Search_Google.csv'
GOOGLE02 = DIR + 'Trip_Search_Google.csv'
COMPARISON = DIR + 'Accom_Compare.xlsx'
googleDF01 = pd.read_csv(GOOGLE01, skiprows=1)   # 불필요한 행 삭제
gooTripDF01 = pd.read_csv(GOOGLE02, skiprows=1)
compareDF01 = pd.read_excel(COMPARISON, skiprows=6)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 정보 보기
googleDF01.info(), gooTripDF01.info(), compareDF01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   주          235 non-null    object
#  1   Geo: 대한민국  235 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 3.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   주           235 non-null    object
#  1   여행: (대한민국)  235 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 3.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      54 non-null     object
#  1   호텔      54 non-null     float64
#  2   날짜.1    54 non-null     object
#  3   모텔      54 non-null     float64
#  4   날짜.2    54 non-null     object
#  5   민박      54 non-null     float64
#  6   날짜.3    54 non-null     object
#  7   게스트하우스  54 non-null     float64
#  8   날짜.4    54 non-null     object
#  9   여인숙     54 non-null     float64
# dtypes: float64(5), object(5)
# memory usage: 4.3+ KB
# (None, None, None)

# %%
googleDF01.head(3)
# Out:
#             주  Geo: 대한민국
# 0  2018-01-07         33
# 1  2018-01-14         30
# 2  2018-01-21         27

# %%
gooTripDF01.head(3)
# Out:
#             주  여행: (대한민국)
# 0  2018-01-07          66
# 1  2018-01-14          47
# 2  2018-01-21          29

# %%
compareDF01.head(3)
# Out:
#            날짜        호텔        날짜.1        모텔        날짜.2       민박  \
# 0  2018-01-01  36.04332  2018-01-01  36.50857  2018-01-01  1.87899
# 1  2018-02-01  32.31231  2018-02-01  29.25860  2018-02-01  2.15537
# 2  2018-03-01  33.40090  2018-03-01  33.58803  2018-03-01  2.46635
#
#          날짜.3    게스트하우스        날짜.4      여인숙
# 0  2018-01-01  17.94175  2018-01-01  4.14713
# 1  2018-02-01  52.00957  2018-02-01  2.20553
# 2  2018-03-01  25.44804  2018-03-01  2.51512

# %%
# 결측치 확인
googleDF01.isna().sum(), gooTripDF01.isna().sum(), compareDF01.isna().sum()
# Out:
# (주            0
#  Geo: 대한민국    0
#  dtype: int64,
#  주             0
#  여행: (대한민국)    0
#  dtype: int64,
#  날짜        0
#  호텔        0
#  날짜.1      0
#  모텔        0
#  날짜.2      0
#  민박        0
#  날짜.3      0
#  게스트하우스    0
#  날짜.4      0
#  여인숙       0
#  dtype: int64)

# %%
# 컬럼명 변경
try:
    googleDF01.rename(columns={'주' : '날짜', 'Geo: 대한민국' : '숙박'},
                     inplace=True)
    gooTripDF01.rename(columns={'주' : '날짜', 'Geo: 대한민국' : '숙박'},
                     inplace=True)
except KeyError:
    pass
gooTripDF01
# Out:
#              날짜  여행: (대한민국)
# 0    2018-01-07          66
# 1    2018-01-14          47
# 2    2018-01-21          29
# 3    2018-01-28          39
# 4    2018-02-04          29
# 36  2021-01-01   38.06033  40.66539  1.45144   8.02169  1.97100
# 37  2021-02-01   39.31633  36.74863  1.80842   8.22612  1.73716
# 38  2021-03-01   37.25885  40.21882  1.41823   9.41329  1.98484
# 39  2021-04-01   38.04857  41.71662  1.69669   9.19122  2.16713
# 40  2021-05-01   41.32850  43.15596  1.92707   9.37870  2.12459
# 41  2021-06-01   48.23913  43.45067  2.70053  11.04773  2.20899
# 42  2021-07-01   58.32834  46.71608  4.38719  10.93946  2.18477
# 43  2021-08-01   51.57234  45.40023  4.11081   9.85295  2.25084
# 44  2021-09-01   43.37319  40.04240  2.35635   8.04037  2.25188
# 45  2021-10-01   51.07422  50.33916  3.01496   9.48836  2.63481
# 46  2021-11-01   52.08048  49.83586  1.87864   9.54370  2.55525
# 47  2021-12-01   58.35325  49.24954  1.73889   9.97644  2.57946
# 48  2022-01-01   48.12187  46.22523  1.82641   9.66443  2.87418
# 49  2022-02-01   42.75228  43.03627  1.69254   8.45754  2.58499
# 50  2022-03-01   46.38643  50.02092  1.93122   8.63361  3.21040
# 51  2022-04-01   48.07621  53.19017  2.49264   9.58902  2.99248
# 52  2022-05-01   54.17083  58.45079  3.39270  13.32625  3.18999
# 53  2022-06-01   57.06057  59.34705  4.97628  13.57842  3.25157

# %%
# 날짜를 인덱스 -> 컬럼으로 옮기고
# int/float -> datetime으로 형변환 astype / to_datetime
# 오름차순 정렬
# 월별로 나누기(pd.to_datetime)
# 그래프

# %%
# '날짜' 컬럼 타입 확인
googleDF01['날짜'].dtypes, gooTripDF01['날짜'].dtypes
# Out:
# (dtype('O'), dtype('O'))

# %%
# '날짜' 컬럼 타입 Object => datetime 변환 astype / pd.to_datetime
try:
    googleDF01['날짜'] = pd.to_datetime(googleDF01['날짜'])
    gooTripDF01['날짜'] = pd.to_datetime(gooTripDF01['날짜'])
except Exception:
    pass
googleDF01['날짜'].info(), gooTripDF01['날짜'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 235 entries, 0 to 234
# Series name: 날짜
# Non-Null Count  Dtype
# --------------  -----
# 235 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.0 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 235 entries, 0 to 234
# Series name: 날짜
# Non-Null Count  Dtype
# --------------  -----
# 235 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.0 KB
# (None, None)

# %%
# 오름차순 정렬
googleDF01['날짜'] = sorted(googleDF01['날짜'])
gooTripDF01['날짜'] = sorted(gooTripDF01['날짜'])

# %%
# 객체변수명.dt.to_period
try:
    googleDF01['날짜'] = googleDF01['날짜'].dt.to_period(freq='M')
    gooTripDF01['날짜'] = gooTripDF01['날짜'].dt.to_period(freq='M')
except Exception:
    pass

# %%
# 데이터프레임.groupby(그룹이되는컬럼)[계산하고 싶은 컬럼].집계함수()
monthDF = googleDF01.groupby(['날짜']).mean()
monthTripDF = gooTripDF01.groupby(['날짜']).mean()
monthTripDF
# Out:
#          여행: (대한민국)
# 날짜
# 2018-01       45.25
# 2018-02       31.75
# 2018-03       39.00
# 2018-04       28.60
# 2018-05       25.50
# 2018-06       40.00
# 2018-07       55.00
# 2018-08       29.75
# 2018-09       45.60
# 2018-10       34.25
# 2018-11       50.50
# 2018-12       46.40
# 2019-01       44.00
# 2019-02       36.50
# 2019-03       34.20
# 2019-04       28.25
# 2019-05       45.50
# 2019-06       35.00
# 2019-07       51.25
# 2019-08       39.25
# 2019-09       55.40
# 2019-10       37.00
# 2019-11       36.50
# 2019-12       51.80
# 2020-01       29.50
# 2020-02       29.75
# 2020-03        9.20
# 2020-04        4.75
# 2020-05        6.40
# 2020-06       14.25
# 2020-07       22.75
# 2020-08       16.80
# 2020-09        6.00
# 2020-10        5.25
# 2020-11        9.80
# 2020-12        8.75
# 2021-01       11.20
# 2021-02       14.25
# 2021-03        8.00
# 2021-04       11.00
# 2021-05        7.80
# 2021-06       12.75
# 2021-07       27.25
# 2021-08       13.60
# 2021-09       23.00
# 2021-10       19.40
# 2021-11       24.25
# 2021-12        9.00
# 2022-01       15.80
# 2022-02       17.25
# 2022-03       11.75
# 2022-04       13.25
# 2022-05       20.00
# 2022-06       30.00
# 2022-07       15.00

# %%
mD = monthDF.reset_index()
mTD = monthTripDF.reset_index()

mD['날짜'] = mD['날짜'].astype(str) # period에서 바로 datetime 형변환하려고 하면 오류 나서
mD['날짜'] = pd.to_datetime(mD['날짜']) # str상태에서 최대최소값 구할 수 업성서, 데이트타임으로 다시 형변환

mTD['날짜'] = mTD['날짜'].astype(str)
mTD['날짜'] = pd.to_datetime(mTD['날짜'])

# %%
mDdr = pd.date_range(start=mD['날짜'].min(), end=mD['날짜'].max(), freq='6M')  # x축 설정, 빈도
mDdr
# Out:
# DatetimeIndex(['2018-01-31', '2018-07-31', '2019-01-31', '2019-07-31',
#                '2020-01-31', '2020-07-31', '2021-01-31', '2021-07-31',
#                '2022-01-31'],
#               dtype='datetime64[ns]', freq='6M')

# %%
# 날짜 -> period 타입 / 인덱스인 상태
# 컬럼으로 꺼냄
# astype으로 오브젝트(str) 형변환     데이트타임도 가능할듯?
# 그리프 그리기  

# aa = monthDF.reset_index()
# aa['날짜'] = aa['날짜'].astype(str)


plt.figure(figsize = (10,8))
plt.plot(mD['날짜'], mD['숙박'])
plt.plot(mTD['날짜'], mTD['여행: (대한민국)'])
plt.xticks(list(mDdr))
plt.legend
# Out:
# ([<matplotlib.axis.XTick at 0x28bfda7e970>,
#   <matplotlib.axis.XTick at 0x28bfda7e940>,
#   <matplotlib.axis.XTick at 0x28bfdaa7e50>,
#   <matplotlib.axis.XTick at 0x28bfdab1760>,
#   <matplotlib.axis.XTick at 0x28bfdab9040>,
#   <matplotlib.axis.XTick at 0x28bfdab9640>,
#   <matplotlib.axis.XTick at 0x28bfdab9d90>,
#   <matplotlib.axis.XTick at 0x28bfdab9a30>,
#   <matplotlib.axis.XTick at 0x28bfdab19d0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
len(monthDF.index)

# %%
len(monthTripDF.index)

# %%
# 숙박업소 유형별 비교
compareDF01.plot(kind='line', figsize=(11,11))
plt.title('2018-2022 숙박 유형별 검색량')
