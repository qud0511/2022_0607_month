# %%
# 모듈 로딩
import pandas as pd

# 파일관련 변수 선언
DIR_PATH='../Data/'
FILE_NAME=DIR_PATH+'weather.csv'
FILE_NAME
# Out:
# '../Data/weather.csv'

# %%
dfweather=pd.read_csv(FILE_NAME)

# %%
dfweather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 35 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       22 non-null     object
#  1   year     22 non-null     int64
#  2   month    22 non-null     int64
#  3   element  22 non-null     object
#  4   d1       2 non-null      float64
#  5   d2       4 non-null      float64
#  6   d3       4 non-null      float64
#  7   d4       2 non-null      float64
#  8   d5       8 non-null      float64
#  9   d6       2 non-null      float64
#  10  d7       2 non-null      float64
#  11  d8       2 non-null      float64
#  12  d9       0 non-null      float64
#  13  d10      2 non-null      float64
#  14  d11      2 non-null      float64
#  15  d12      0 non-null      float64
#  16  d13      2 non-null      float64
#  17  d14      4 non-null      float64
#  18  d15      2 non-null      float64
#  19  d16      2 non-null      float64
# ...

# %%
dfweather.isnull().sum()
# Out:
# id          0
# year        0
# month       0
# element     0
# d1         20
# d2         18
# d3         18
# d4         20
# d5         14
# d6         20
# d7         20
# d8         20
# d9         22
# d10        20
# d11        20
# d12        22
# d13        20
# d14        18
# d15        20
# d16        20
# d17        20
# d18        22
# d19        22
# d20        22
# d21        22
# d22        22
# d23        18
# d24        22
# d25        20
# d26        20
# d27        16
# d28        20
# d29        18
# d30        20
# d31        20
# dtype: int64

# %%
oneMonth=dfweather.iloc[[0,1]]
oneMonth
# Out:
#         id  year  month element  d1  d2  d3  d4  d5  d6  ...  d22  d23  d24  \
# 0  MX17004  2010      1    tmax NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
# 1  MX17004  2010      1    tmin NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
#
#    d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  14.5  NaN
#
# [2 rows x 35 columns]

# %%
oneMonth.dropna(axis=1, how='all')
# Out:
#         id  year  month element   d30
# 0  MX17004  2010      1    tmax  27.8
# 1  MX17004  2010      1    tmin  14.5

# %%
twoMonth=dfweather.iloc[[2,3]].dropna(axis=1, how='all')
twoMonth
# Out:
#         id  year  month element    d2    d3   d11   d23
# 2  MX17004  2010      2    tmax  27.3  24.1  29.7  29.9
# 3  MX17004  2010      2    tmin  14.4  14.4  13.4  10.7

# %%
a=twoMonth[['d2', 'd3', 'd11', 'd23']]
a
# Out:
#      d2    d3   d11   d23
# 2  27.3  24.1  29.7  29.9
# 3  14.4  14.4  13.4  10.7

# %%
print(a.iloc[0].max(), a.iloc[1].min())
# Out:
# 29.9 10.7

# %%
df=dfweather.drop(['id', 'year', 'month','element'], axis=1)

# %%
a=df.dropna(axis=1, how='all')
a
# Out:
#       d1    d2    d3    d4    d5    d6    d7    d8   d10   d11  ...   d16  \
# 0    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2    NaN  27.3  24.1   NaN   NaN   NaN   NaN   NaN   NaN  29.7  ...   NaN
# 3    NaN  14.4  14.4   NaN   NaN   NaN   NaN   NaN   NaN  13.4  ...   NaN
# 4    NaN   NaN   NaN   NaN  32.1   NaN   NaN   NaN  34.5   NaN  ...  31.1
# 5    NaN   NaN   NaN   NaN  14.2   NaN   NaN   NaN  16.8   NaN  ...  17.6
# 6    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 7    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ...

# %%
for i in range(11):
    print(a.iloc[2*i].max(), a.iloc[(2*i)+1].min())
# Out:
# 27.8 14.5
# 29.9 10.7
# 34.5 14.2
# 36.3 16.7
# 33.2 18.2
# 30.1 17.5
# 29.9 16.5
# 29.8 15.0
# 31.2 10.5
# 31.3 7.9
# 29.9 10.5
