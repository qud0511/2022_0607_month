# %%
# 모듈 로딩 -----------------
import pandas as pd

# 파일관련 변수 선언 -----------
DIR_PATH = '../Data/'
FILE_NAME = DIR_PATH + 'weather.csv'

FILE_NAME
# Out:
# '../Data/weather.csv'

# %%
# (1) CSV File => DataFrame으로 로딩 -------
weatherDF = pd.read_csv(FILE_NAME)
weatherDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 35 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       22 non-null     object
#  1   year     22 non-null     int64
#  2   month    22 non-null     int64
#  3   element  22 non-null     object
#  4   d1       2 non-null      float64
#  5   d2       4 non-null      float64
#  6   d3       4 non-null      float64
#  7   d4       2 non-null      float64
#  8   d5       8 non-null      float64
#  9   d6       2 non-null      float64
#  10  d7       2 non-null      float64
#  11  d8       2 non-null      float64
#  12  d9       0 non-null      float64
#  13  d10      2 non-null      float64
#  14  d11      2 non-null      float64
#  15  d12      0 non-null      float64
#  16  d13      2 non-null      float64
#  17  d14      4 non-null      float64
#  18  d15      2 non-null      float64
#  19  d16      2 non-null      float64
# ...

# %%
# 과제 0704 - (1) 2010년 1월 ~ 12월 최고온도 - 최저온도 데이터 추출
col = ['id', 'year', 'month', 'element']

for i in range(int(len(weatherDF.index)/2)):
    print(f'{weatherDF["month"][2*i]}월의 최대값: {weatherDF.iloc[2*i].dropna().drop(col).max()}')
    print(f'{weatherDF["month"][2*i]}월의 최소값: {weatherDF.iloc[2*i+1].dropna().drop(col).min()}')
# Out:
# 1월의 최대값: 27.8
# 1월의 최소값: 14.5
# 2월의 최대값: 29.9
# 2월의 최소값: 10.7
# 3월의 최대값: 34.5
# 3월의 최소값: 14.2
# 4월의 최대값: 36.3
# 4월의 최소값: 16.7
# 5월의 최대값: 33.2
# 5월의 최소값: 18.2
# 6월의 최대값: 30.1
# 6월의 최소값: 17.5
# 7월의 최대값: 29.9
# 7월의 최소값: 16.5
# 8월의 최대값: 29.8
# 8월의 최소값: 15.0
# 10월의 최대값: 31.2
# 10월의 최소값: 10.5
# 11월의 최대값: 31.3
# 11월의 최소값: 7.9
# 12월의 최대값: 29.9
# 12월의 최소값: 10.5

# %%
# 과제 0704 - (2) 서울에서 다른지역으로 이동한 년도별 인구수 / 데이터 추출 및 분석
import numpy as np


filename = DIR_PATH + '시도별 전출입 인구수.xlsx'
excelDF = pd.read_excel(filename)

# %%
excelDF.index
# Out:
# RangeIndex(start=0, stop=325, step=1)

# %%
excelDF.fillna(method = 'ffill', inplace = True)

# %%
excelDF.replace('-', None)
# Out:
#         전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0       전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1         전국       전국   4046536   4210164   3687938   4860418   5297969
# 2         전국    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3         전국    부산광역시    448577    389797    362202    482061    680984
# 4         전국    대구광역시      None      None      None      None      None
# ..       ...      ...       ...       ...       ...       ...       ...
# 320  제주특별자치도     전라북도       139       202       141       210       219
# 321  제주특별자치도     전라남도       631       965       857       952      1133
# 322  제주특별자치도     경상북도       374       619       468       576       625
# 323  제주특별자치도     경상남도       474       479       440       571      1208
# 324  제주특별자치도  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %%
col = excelDF.columns[2:]
col
# Out:
# Index(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017'],
#       dtype='object')

# %%
excelDF2 = excelDF[excelDF['전출지별'] == '서울특별시']
excelDF2
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 20  서울특별시    서울특별시  1232619  1158556   985945  1345508  1511726  2401970
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
# 30  서울특별시     충청북도     6700     9457    10853    12617    11786    21073
# ...

# %%
excelDFA = excelDF2[excelDF2['전입지별'] == '전국']
excelDFA
# Out:
#      전출지별 전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19  서울특별시   전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
#
#        1977  ...     2008     2009     2010     2011     2012     2013  \
# 19  2678007  ...  2083352  1925452  1848038  1834806  1658928  1620640
#
#        2014     2015     2016     2017
# 19  1661425  1726687  1655859  1571423
#
# [1 rows x 50 columns]

# %%
excelDFB = excelDF2[excelDF2['전입지별'] == '서울특별시']
excelDFB
# Out:
#      전출지별   전입지별     1970     1971    1972     1973     1974     1975  \
# 20  서울특별시  서울특별시  1232619  1158556  985945  1345508  1511726  2401970
#
#        1976     1977  ...     2008     2009     2010     2011     2012  \
# 20  2041724  2212213  ...  1426213  1286855  1199708  1215122  1069300
#
#        2013     2014     2015     2016     2017
# 20  1053008  1098023  1129529  1061915  1018807
#
# [1 rows x 50 columns]

# %%
for i in col:
    print(f'{i}년 서울에서 다른 지역으로 이동한 인구수 : {excelDFA[i].iloc[0] - excelDFB[i].iloc[0]}명')
# Out:
# 1970년 서울에서 다른 지역으로 이동한 인구수 : 216366명
# 1971년 서울에서 다른 지역으로 이동한 인구수 : 260460명
# 1972년 서울에서 다른 지역으로 이동한 인구수 : 224614명
# 1973년 서울에서 다른 지역으로 이동한 인구수 : 301760명
# 1974년 서울에서 다른 지역으로 이동한 인구수 : 307934명
# 1975년 서울에서 다른 지역으로 이동한 인구수 : 535123명
# 1976년 서울에서 다른 지역으로 이동한 인구수 : 453896명
# 1977년 서울에서 다른 지역으로 이동한 인구수 : 465794명
# 1978년 서울에서 다른 지역으로 이동한 인구수 : 510625명
# 1979년 서울에서 다른 지역으로 이동한 인구수 : 557500명
# 1980년 서울에서 다른 지역으로 이동한 인구수 : 617146명
# 1981년 서울에서 다른 지역으로 이동한 인구수 : 620879명
# 1982년 서울에서 다른 지역으로 이동한 인구수 : 665435명
# 1983년 서울에서 다른 지역으로 이동한 인구수 : 781727명
# 1984년 서울에서 다른 지역으로 이동한 인구수 : 711428명
# 1985년 서울에서 다른 지역으로 이동한 인구수 : 746466명
# 1986년 서울에서 다른 지역으로 이동한 인구수 : 753844명
# 1987년 서울에서 다른 지역으로 이동한 인구수 : 753545명
# 1988년 서울에서 다른 지역으로 이동한 인구수 : 768133명
# 1989년 서울에서 다른 지역으로 이동한 인구수 : 752613명
# 1990년 서울에서 다른 지역으로 이동한 인구수 : 845063명
# 1991년 서울에서 다른 지역으로 이동한 인구수 : 710066명
# 1992년 서울에서 다른 지역으로 이동한 인구수 : 735743명
# 1993년 서울에서 다른 지역으로 이동한 인구수 : 793754명
# 1994년 서울에서 다른 지역으로 이동한 인구수 : 810477명
# ...
