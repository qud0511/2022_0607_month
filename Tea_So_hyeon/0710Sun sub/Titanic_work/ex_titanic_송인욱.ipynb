# %% [markdown]
# # Seaborn 실습 -----------------

# %%
import pandas as pd
import numpy as np
import seaborn

# %%
df = seaborn.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
print(df.index, df.columns, sep='\n')
# Out:
# RangeIndex(start=0, stop=891, step=1)
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## 성별, 동석, 나이에 따른 생존률

# %% [markdown]
# ### 데이터 정제

# %%
# 결측치 처리
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# 결측치 처리
df['age'] = df['age'].fillna(df['age'].mean())
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])

# %%
df['deck'] = df['deck'].astype(str).replace({'nan': np.nan})
df['deck'] = df['deck'].fillna('DN')

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         891 non-null    object
#  12  embark_town  891 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(6)
# memory usage: 86.4+ KB

# %%
# 데이터 표준화
df['age'] = df['age'].astype(int)

# %%
# 중복체크
df.duplicated().sum()
# Out:
# 112

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0           0       3    male   22      1      0   7.2500        S  Third
# 1           1       1  female   38      1      0  71.2833        C  First
# 2           1       3  female   26      0      0   7.9250        S  Third
# 3           1       1  female   35      1      0  53.1000        S  First
# 4           0       3    male   35      0      0   8.0500        S  Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...    ...
# 774         0       3  female   39      0      5  29.1250        Q  Third
# 775         1       1  female   19      0      0  30.0000        S  First
# 776         0       3  female   29      1      2  23.4500        S  Third
# 777         1       1    male   26      0      0  30.0000        C  First
# 778         0       3    male   32      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True   DN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False   DN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True   DN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 774  woman       False   DN   Queenstown    no  False
# 775  woman       False    B  Southampton   yes   True
# 776  woman       False   DN  Southampton    no  False
# 777    man        True    C    Cherbourg   yes   True
# 778    man        True   DN   Queenstown    no   True
#
# [779 rows x 15 columns]

# %%
# 데이터 표준화

# %%
age_cut = pd.cut(df['age'], [0,20, 40, 60, 80], labels=['child', 'young', 'elder', 'old'])
df.insert(4, 'age_cut', age_cut)

# %%
df
# Out:
#      survived  pclass     sex  age age_cut  sibsp  parch     fare embarked  \
# 0           0       3    male   22   young      1      0   7.2500        S
# 1           1       1  female   38   young      1      0  71.2833        C
# 2           1       3  female   26   young      0      0   7.9250        S
# 3           1       1  female   35   young      1      0  53.1000        S
# 4           0       3    male   35   young      0      0   8.0500        S
# ..        ...     ...     ...  ...     ...    ...    ...      ...      ...
# 774         0       3  female   39   young      0      5  29.1250        Q
# 775         1       1  female   19   child      0      0  30.0000        S
# 776         0       3  female   29   young      1      2  23.4500        S
# 777         1       1    male   26   young      0      0  30.0000        C
# 778         0       3    male   32   young      0      0   7.7500        Q
#
#      class    who  adult_male deck  embark_town alive  alone
# 0    Third    man        True   DN  Southampton    no  False
# 1    First  woman       False    C    Cherbourg   yes  False
# 2    Third  woman       False   DN  Southampton   yes   True
# 3    First  woman       False    C  Southampton   yes  False
# 4    Third    man        True   DN  Southampton    no   True
# ..     ...    ...         ...  ...          ...   ...    ...
# 774  Third  woman       False   DN   Queenstown    no  False
# 775  First  woman       False    B  Southampton   yes   True
# 776  Third  woman       False   DN  Southampton    no  False
# 777  First    man        True    C    Cherbourg   yes   True
# 778  Third    man        True   DN   Queenstown    no   True
#
# [779 rows x 16 columns]

# %% [markdown]
# ### 데이터 추출

# %% [markdown]
# #### 값으로 구하기

# %%
aliveRatio = df.groupby('sex')
maleDF = aliveRatio.get_group('male')
femaleDF = aliveRatio.get_group('female')

# %%
male = maleDF['survived'].value_counts()
maleAliveRatio = (male.loc[1] / (male.loc[0] + male.loc[1])) * 100
maleAliveRatio
# Out:
# 21.604938271604937

# %%
female = femaleDF['survived'].value_counts()
femaleAliveRatio = (female.loc[1] / (female.loc[0] + female.loc[1])) * 100
femaleAliveRatio
# Out:
# 74.06143344709898

# %% [markdown]
# #### 데이터 프레임 형태로 구하기

# %%
aliveDead = df.groupby('survived')

# %%
alive = aliveDead.get_group(1)
alive.describe()
# Out:
#        survived      pclass         age       sibsp       parch        fare
# count     322.0  322.000000  322.000000  322.000000  322.000000  322.000000
# mean        1.0    1.900621   28.425466    0.481366    0.487578   50.210638
# std         0.0    0.855293   14.075310    0.715621    0.786273   68.074711
# min         1.0    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%         1.0    1.000000   20.250000    0.000000    0.000000   13.000000
# 50%         1.0    2.000000   29.000000    0.000000    0.000000   26.250000
# 75%         1.0    3.000000   36.000000    1.000000    1.000000   62.368725
# max         1.0    3.000000   80.000000    4.000000    5.000000  512.329200

# %%
dead = aliveDead.get_group(0)
dead.describe()
# Out:
#        survived      pclass         age       sibsp       parch        fare
# count     457.0  457.000000  457.000000  457.000000  457.000000  457.000000
# mean        0.0    2.477024   30.673961    0.557987    0.369803   24.084253
# std         0.0    0.772341   13.501171    1.142014    0.871708   33.448586
# min         0.0    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%         0.0    2.000000   22.000000    0.000000    0.000000    7.875000
# 50%         0.0    3.000000   29.000000    0.000000    0.000000   13.000000
# 75%         0.0    3.000000   38.000000    1.000000    0.000000   27.000000
# max         0.0    3.000000   74.000000    8.000000    6.000000  263.000000
